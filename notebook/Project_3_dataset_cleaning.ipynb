# %%
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.12/dist-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.12/dist-packages (from openpyxl) (2.0.0)

# %%
import pandas as pd
import numpy as np
import re

# %%
file_path = "/content/Residential_raw.csv"   # change if needed
df = pd.read_csv(file_path)

# %%
df.columns = (
    df.columns.str.strip()
              .str.lower()
              .str.replace(" ", "_")
)

# %%
def clean_price(x):
    if pd.isna(x):
        return None

    x = str(x).replace(",", "").replace("₹","").strip().lower()

    # lakh / l
    if "lakh" in x or "lac" in x or x.endswith("l"):
        nums = re.findall(r"[\d\.]+", x)
        if nums:
            return float(nums[0]) * 100000  # 1 lakh = 1,00,000

    # crore / cr
    if "cr" in x or "crore" in x:
        nums = re.findall(r"[\d\.]+", x)
        if nums:
            return float(nums[0]) * 10000000  # 1 crore = 1,00,00,000

    # plain numeric values
    nums = re.findall(r"[\d\.]+", x)
    return float(nums[0]) if nums else None

df["price_clean"] = df["price"].apply(clean_price)

# ===============================
# STEP 4 — CLEAN TOTAL AREA
# ===============================
def clean_area(x):
    if pd.isna(x):
        return None
    x = str(x).lower().replace(",", "")
    nums = re.findall(r"[\d\.]+", x)
    return float(nums[0]) if nums else None

df["total_area_clean"] = df["total_area"].apply(clean_area)

# %%
df["location_clean"] = (
    df["location"]
      .astype(str)
      .str.strip()
      .str.title()
)

# %%
df["description_clean"] = (
    df["description"]
      .astype(str)
      .str.replace("\n", " ")
      .str.strip()
)

# %%
df["price_per_sqft_clean"] = (
    df["price_clean"] / df["total_area_clean"]
)

# %%
final_df = df[[
    "name",
    "property_title",
    "price_clean",
    "location_clean",
    "total_area_clean",
    "price_per_sqft_clean",
    "description_clean",
    "baths",
    "balcony"
]]

final_df = final_df.rename(columns={
    "price_clean": "price",
    "location_clean": "location",
    "total_area_clean": "total_area",
    "price_per_sqft_clean": "price_per_sqft",
    "description_clean": "description"
})

# %%
final_df["price"] = pd.to_numeric(final_df["price"], errors="coerce")
final_df["total_area"] = pd.to_numeric(final_df["total_area"], errors="coerce")
final_df["price_per_sqft"] = pd.to_numeric(final_df["price_per_sqft"], errors="coerce")

# %%
output_path = "/content/residential_cleaned.csv"
final_df.to_csv(output_path, index=False)

print("Cleaning complete!")
print("Saved file to:", output_path)

# SHOW FIRST 15 ROWS
final_df.head(15)
# Out:
# Cleaning complete!
# Saved file to: /content/residential_cleaned.csv
#                                               name  \
# 0                                 Casagrand ECR 14
# 1            Ramanathan Nagar, Pozhichalur,Chennai
# 2                                      DAC Prapthi
# 3          Naveenilaya,Chepauk, Triplicane,Chennai
# 4                         VGN Spring Field Phase 1
# 5                                   KG Earth Homes
# 6     THIRAN FLATS ,Gowrivakkam, Sembakkam,Chennai
# 7                                 TK Jasmine Grove
# 8                                           Avenue
# 9                               Guru Kothai Aparts
# 10       Mahindra Lifespaces Aqualilly Flexi Homes
# 11                                  DRA 90 Degrees
# 12        Ramakrishna Puram, West Mambalam,Chennai
# 13  Deepak home,Mettuppalayam, Ashok Nagar,Chennai
# 14        Chimaera Apartments,Madambakkam, Chennai
#
#                                        property_title       price  \
# 0   4 BHK Flat for sale in Kanathur Reddikuppam, C...  19900000.0
# 1   10 BHK Independent House for sale in Pozhichal...  22500000.0
# 2       3 BHK Flat for sale in West Tambaram, Chennai  10000000.0
# 3   7 BHK Independent House for sale in Triplicane...  33300000.0
# 4               2 BHK Flat for sale in Avadi, Chennai   4800000.0
# 5            2 BHK Flat for sale in Siruseri, Chennai   4000000.0
# 6           2 BHK Flat for sale in Sembakkam, Chennai   6000000.0
# 7   3 BHK Independent House for sale in Mahindra W...   7235000.0
# 8       2 BHK Flat for sale in West Tambaram, Chennai   4200000.0
# 9           1 BHK Flat for sale in Chromepet, Chennai   3000000.0
# 10  1 BHK Flat for sale in Mahindra World City, Ch...   2940000.0
# 11       3 BHK Flat for sale in Pallikaranai, Chennai  13000000.0
# 12     6 BHK Villa for sale in West Mambalam, Chennai  85000000.0
# 13        2 BHK Flat for sale in Ashok Nagar, Chennai  11500000.0
# 14        2 BHK Flat for sale in Madambakkam, Chennai   4900000.0
#
#                                           location  total_area  \
# 0                    Kanathur Reddikuppam, Chennai      2583.0
# 1            Ramanathan Nagar, Pozhichalur,Chennai      7000.0
# 2         Kasthuribai Nagar, West Tambaram,Chennai      1320.0
# 3          Naveenilaya,Chepauk, Triplicane,Chennai      4250.0
# 4                                   Avadi, Chennai       960.0
# 5                                Siruseri, Chennai       940.0
# 6     Thiran Flats ,Gowrivakkam, Sembakkam,Chennai       880.0
# 7                     Mahindra World City, Chennai      1700.0
# 8          Brindavan Colony, West Tambaram,Chennai       840.0
# 9                    New Colony, Chromepet,Chennai       535.0
# 10                    Mahindra World City, Chennai       581.0
# 11               Rose Avenue, Pallikaranai,Chennai      1444.0
# 12        Ramakrishna Puram, West Mambalam,Chennai      6000.0
# 13  Deepak Home,Mettuppalayam, Ashok Nagar,Chennai       878.0
# 14        Chimaera Apartments,Madambakkam, Chennai       944.0
#
#     price_per_sqft                                        description  baths  \
# 0      7704.219899  Best 4 BHK Apartment for modern-day lifestyle ...      4
# 1      3214.285714  Looking for a 10 BHK Independent House for sal...      6
# 2      7575.757576  Property for sale in Tambaram, Chennai. This 3...      3
# 3      7835.294118  Entire Building for sale with 7 units of singl...      5
# 4      5000.000000  Property for sale in Avadi, Chennai. This 2 BH...      3
# 5      4255.319149  Price negotiable. Big hall, big balcony, gated...      3
# 6      6818.181818  2 BHK Apartment for sale in Chennai. This prop...      3
# 7      4255.882353  A 3 BHK Independent House for sale in Mahindra...      3
# 8      5000.000000  Check out this 2 BHK Apartment for sale in Tam...      3
# 9      5607.476636  We are the proud owners of this 1 bhk apartmen...      2
# 10     5060.240964  A 1 BHK Apartment for sale in Mahindra World C...      2
# 11     9002.770083  Looking for a 3 BHK Apartment for sale in Chen...      3
# 12    14166.666667  Looking for a 6 BHK Villa for sale in Chennai?...      1
# 13    13097.949886  13a,4th Street, Ragavan colony, Ashok Nagar, C...      3
# 14     5190.677966  Best 2 BHK Apartment for modern-day lifestyle ...      3
#
#    balcony
# 0      Yes
# 1      Yes
# 2       No
# 3      Yes
# 4      Yes
# 5       No
# 6      Yes
# 7      Yes
# 8       No
# 9       No
# 10     Yes
# 11      No
# 12     Yes
# 13     Yes
# 14      No
